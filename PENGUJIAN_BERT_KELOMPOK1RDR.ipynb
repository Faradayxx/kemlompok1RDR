# %% [markdown]
# <a href="https://colab.research.google.com/github/Faradayxx/kemlompok1RDR/blob/main/PENGUJIAN_BERT_KELOMPOK1RDR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers
# !pip install nltk
# !pip install bert-score
# !pip install scikit-learn
# !pip install scipy
# !pip install numpy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 2.0 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# ...

# %%
from sklearn.metrics.pairwise import cosine_similarity
from transformers import BertTokenizer, BertForMaskedLM, BertModel
from bert_score import BERTScorer

# %%
text1 = "Bagaimana Ir. Soekarno menghapuskan Undang-Undang Dasar 1945?"
text2 = "Ir. Soekarno menghapuskan Undang-Undang Dasar 1945 pada tahun 1961 dalam rangka mendukung pemerintahan militer di Indonesia yang dikenal sebagai Perwakilan Rakyat (PERRI) dan Perda No. 1 Tahun 1961. Undang-Undang Dasar 1945 menetapkan bahwa Indonesia adalah negara secular."

# %%
scorer = BERTScorer(model_type='bert-base-uncased')
P, R, F1 = scorer.score([text1], [text2])
print(f"BERTScore Precision: {P.mean():.4f}, Recall: {R.mean():.4f}, F1: {F1.mean():.4f}")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# BERTScore Precision: 0.8052, Recall: 0.6226, F1: 0.7022

# %%
pe1 = "siapakah istri soekarno?"
ja1 = "Istri Soekarno adalah Ibu Tien Soeharto, dengan nama lengkap Roosminarti Sjahrir. Kawinan mereka dilakukan di Tijuping, Sumatera Barat, pada tanggal 18 Maret 1930."

# %%
scorer = BERTScorer(model_type='bert-base-uncased')
P, R, F1 = scorer.score([pe1], [ja1])
print(f"BERTScore Precision: {P.mean():.4f}, Recall: {R.mean():.4f}, F1: {F1.mean():.4f}")
# Out:
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# BERTScore Precision: 0.7545, Recall: 0.5812, F1: 0.6566

# %%
pe2 = "perbedaan antara kemerdekaan dan independensi?"
ja2 = "Kemerdekaan dan independensi adalah dua konsep yang sering dikaitkan satu sama lain, namun ada perbedaan antara keduanya. Kemerdekaan adalah sebuah konsepsi politik yang mengharuskan suatu negara atau wilayah untuk memiliki kuasa dan kebijakan penuh di dalamnya tanpa ada kontrol luar. Independensi, pada sisi lain, adalah konsepsi politik yang mengharuskan sebuah negara atau wilayah untuk menjadi terpisah dan tidak terikat dengan suatu sistem politik atau kebijakan lainnya. Sebuah negara yang kemerdeka dan independen secara luas dikenal dengan sebutan negeri-negeri."

# %%
scorer = BERTScorer(model_type='bert-base-uncased')
P, R, F1 = scorer.score([pe2], [ja2])
print(f"BERTScore Precision: {P.mean():.4f}, Recall: {R.mean():.4f}, F1: {F1.mean():.4f}")
# Out:
# BERTScore Precision: 0.7661, Recall: 0.4974, F1: 0.6032

# %%
pe3 = "Kapan Ir.Soekarno Lahir?"
ja3 = "Ir. Soekarno lahir pada tanggal 6 Juni 1901 di wonogiri, Jawa Tenggoro."

# %%
scorer = BERTScorer(model_type='bert-base-uncased')
P, R, F1 = scorer.score([pe3], [ja3])
print(f"BERTScore Precision: {P.mean():.4f}, Recall: {R.mean():.4f}, F1: {F1.mean():.4f}")
# Out:
# BERTScore Precision: 0.7759, Recall: 0.5904, F1: 0.6705

# %%
pe4 = "dimana soeakrno berkuliah?"
ja4 = "Ir. Soekarno memperoleh pendidikan menengah di HBS (Hollandsche Buitersschool) dan jurusan Ilmu Politika di Universitas Leiden, Belanda (Holandia)."

# %%
scorer = BERTScorer(model_type='bert-base-uncased')
P, R, F1 = scorer.score([pe4], [ja4])
print(f"BERTScore Precision: {P.mean():.4f}, Recall: {R.mean():.4f}, F1: {F1.mean():.4f}")
# Out:
# BERTScore Precision: 0.5344, Recall: 0.3987, F1: 0.4567

# %%
pe5 = "apakah soeakrno pernah menjadi presiden indonesia?"
ja5 = "Ya, Ir. Soekarno menjabat sebagai ketua republik Indonesia selama dua kali, yaitu dari tahun 1945 sampai 1966."

# %%
scorer = BERTScorer(model_type='bert-base-uncased')
P, R, F1 = scorer.score([pe5], [ja5])
print(f"BERTScore Precision: {P.mean():.4f}, Recall: {R.mean():.4f}, F1: {F1.mean():.4f}")
# Out:
# BERTScore Precision: 0.6626, Recall: 0.5885, F1: 0.6234

# %%
pe6 = "apakah soeakrno pernah menghadapi masalah politik di indonesia?"
ja6 = "Ya, Ir. Soekarno pernah menghadapi masalah politik di Indonesia, seperti perjuangan kemerdekaan Indonesia, perguruan politik di Universitas Indonesia, dan pembuatan Konstituensi 1945."

# %%
scorer = BERTScorer(model_type='bert-base-uncased')
P, R, F1 = scorer.score([pe6], [ja6])
print(f"BERTScore Precision: {P.mean():.4f}, Recall: {R.mean():.4f}, F1: {F1.mean():.4f}")
# Out:
# BERTScore Precision: 0.8365, Recall: 0.6694, F1: 0.7437

# %%
pe7 = "apakah soeakrno pernah menangani masalah ekonomi di indonesia?"
ja7 = "Ya, Ir. Soekarno pernah menangani masalah ekonomi di Indonesia, seperti pembuatan Rencana Tiga Tahun dan Dwifungsi."

# %%
scorer = BERTScorer(model_type='bert-base-uncased')
P, R, F1 = scorer.score([pe7], [ja7])
print(f"BERTScore Precision: {P.mean():.4f}, Recall: {R.mean():.4f}, F1: {F1.mean():.4f}")
# Out:
# BERTScore Precision: 0.8669, Recall: 0.7206, F1: 0.7870

# %%
pe8 = "apakah soeakrno pernah menangani masalah sosial di indonesia?"
ja8 = " Ya, Ir. Soekarno pernah menangani masalah sosial di Indonesia, seperti pembuatan Pancasila dan pembuatan Undang-Undang"

# %%
scorer = BERTScorer(model_type='bert-base-uncased')
P, R, F1 = scorer.score([pe8], [ja8])
print(f"BERTScore Precision: {P.mean():.4f}, Recall: {R.mean():.4f}, F1: {F1.mean():.4f}")
# Out:
# BERTScore Precision: 0.8566, Recall: 0.6762, F1: 0.7558

# %%
pe9 = "Siapakah kamu?"
ja9 = "Saya adalah chatbot Ir. Soekarno, yang dibangun dengan menggabungkan teknologi dan keterampilan dalam bidang ilmu komputer dan sejarah Indonesia. Saya dikembangkan untuk membantu mahasiswa dan masyarakat mengetahui lebih tentang Ir. Soekarno, sebagai pemimpin utama Indonesia ketika kemerdekaan. Saya mampu menjawab pertanyaan yang berkaitan dengan sejarah, filosofi, dan karya Ir. Soekarno dengan tepat dan lengkap. Saya menggabungkan teknologi dan keterampilan dalam bidang ilmu komputer dan sejarah Indonesia untuk membantu mahasiswa dan masyarakat mengetahui lebih tentang Ir. Soekarno, sebagai pemimpin utama Indonesia ketika kemerdekaan. Saya dikembangkan untuk membantu mahasiswa dan masyarakat mengetahui lebih tentang Ir. Soekarno, sebagai pemimpin utama Indonesia ketika kemerdekaan. Saya mampu menjawab pertanyaan yang berkaitan dengan sejarah, filosofi, dan karya Ir. Soekarno dengan tepat dan lengkap."

# %%
scorer = BERTScorer(model_type='bert-base-uncased')
P, R, F1 = scorer.score([pe9], [ja9])
print(f"BERTScore Precision: {P.mean():.4f}, Recall: {R.mean():.4f}, F1: {F1.mean():.4f}")
# Out:
# BERTScore Precision: 0.4466, Recall: 0.2654, F1: 0.3329
